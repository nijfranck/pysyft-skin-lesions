# %%
# %matplotlib inline
# Python libraries

import os, cv2, itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
from glob import glob
from PIL import Image

# Pytorch libraries
import torch
from torch import optim, nn
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset
from torchvision import models, transforms

# sklearn libraries
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# to make the results are reproducible
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)

print(os.listdir('../data'))
# Out:
# ['MNIST', 'image_processing_templates.ipynb', '.ipynb_checkpoints', 'image_processing_templates-without balancing.ipynb', 'table.csv', 'images', '.DS_Store']

# %%
directory = '../data/images/'

image_path = glob(os.path.join(directory, '*.jpg'))
imageid = {os.path.splitext(os.path.basename(x))[0]: x for x in image_path}
print(len(image_path))
# Out:
# 18997

# %%
lesion_type = {
    'MEL': 'Melanoma',
    'NV': 'Naevus',
    'BCC': 'Basal Cell Carcinoma',
    'AK': 'IEC/Bowens disease',
    'BKL': 'Seborrhoeic keratosis',
    'DF': 'dermatofibroima',
    'VASC': 'vascular lesions',
    'SCC': 'Squamous cell carcinom',
    'UNK': 'Keratosis pilaris'
}

lesion_category = {
    'MEL': 0,
    'NV':  1,
    'BCC': 2,
    'AK':  3,
    'BKL': 4,
    'DF':  5,
    'VASC': 6,
    'SCC': 7,
    'UNK': 8
}

# %%
def compute_img_mean_std(image_paths):
    """
        computing the mean and std of three channel on the whole dataset,
        first we should normalize the image from 0-255 to 0-1
    """

    img_h, img_w = 224, 224
    imgs = []
    means, stdevs = [], []

    for i in tqdm(range(len(image_paths))):
        img = cv2.imread(image_paths[i])
        img = cv2.resize(img, (img_h, img_w))
        imgs.append(img)

    imgs = np.stack(imgs, axis=3)
    print(imgs.shape)

    imgs = imgs.astype(np.float32) / 255.

    for i in range(3):
        pixels = imgs[:, :, i, :].ravel()  # resize to one row
        means.append(np.mean(pixels))
        stdevs.append(np.std(pixels))

    means.reverse()  # BGR --> RGB
    stdevs.reverse()

    print("normMean = {}".format(means))
    print("normStd = {}".format(stdevs))
    return means,stdevs

#norm_mean, norm_std = compute_img_mean_std(image_path)
# shape (224, 224, 3, 18997)
norm_mean = [0.7851518, 0.6649233, 0.6525781]
norm_std = [0.17073259, 0.21847703, 0.2293689]

# %%
df = pd.read_csv('table.csv')
lesion_code_list = lesion_type.keys()
df['path'] = df['image'].map(imageid.get)
df['cell_type'] = df[lesion_code_list].idxmax(axis=1).map(lesion_type.get)
df['cell_type_idx'] = df[lesion_code_list].idxmax(axis=1).map(lesion_category.get)
print(df.shape)
bool_series = pd.isnull(df["image"])  
df[bool_series]
# Out:
# (18997, 24)
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, Unnamed: 0.1.1, image, ImageName, lesion_id, DiagnosisDescriptions, DiagnosisSCARD, MEL, NV, BCC, AK, BKL, DF, VASC, SCC, UNK, Count_classes, w, h, hash, path, cell_type, cell_type_idx]
# Index: []
#
# [0 rows x 24 columns]

# %%
# train, val split
y = df['cell_type_idx']
df_train, df_val = train_test_split(df, test_size=0.2, random_state = 101, stratify=y)
df_val, df_test = train_test_split(df_val, test_size = 0.5, random_state = 101, stratify=df_val['cell_type_idx'])
print(df_train.shape, df_val.shape, df_test.shape)
# Out:
# (15197, 24) (1900, 24) (1900, 24)

# %%
df_val['cell_type_idx'].value_counts()
# Out:
# 1    486
# 2    398
# 3    320
# 8    260
# 4    232
# 7     89
# 0     73
# 5     28
# 6     14
# Name: cell_type_idx, dtype: int64

# %%
df_val['cell_type'].value_counts()
# Out:
# Naevus                    486
# Basal Cell Carcinoma      398
# IEC/Bowens disease        320
# Keratosis pilaris         260
# Seborrhoeic keratosis     232
# Squamous cell carcinom     89
# Melanoma                   73
# dermatofibroima            28
# vascular lesions           14
# Name: cell_type, dtype: int64

# %%
# check if a row belongs to the train or val or test set
def get_val_rows(x):
    # create a list of all the imageid in the val set
    val_list = list(df_val['image'])
    test_list = list(df_test['image'])
    if str(x) in val_list:
        return 'val'
    elif str(x) in test_list:
        return 'test'
    else:
        return 'train'
    
# identify train and val rows
# create a new column that 
df['train_or_val_or_test'] = df['image']
df['train_or_val_or_test'] = df['train_or_val_or_test'].apply(get_val_rows)
# filter out train rows
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1         image  \
# 0           0             0               0  ISIC_1000000
# 1           1             1               1  ISIC_1000001
# 2           2             2               2  ISIC_1000002
# 3           3             3               3  ISIC_1000003
# 4           4             4               4  ISIC_1000004
#
#                                    ImageName  lesion_id  \
# 0  002sMOUIQD5w7qL120190411010815030247.jpeg    2024373
# 1  00rK0idbwy0PxNi420181219033635545026.jpeg    1668238
# 2  01udcynfZrZmuOiQ20190304222024216112.jpeg    1914403
# 3  027ryniVjJC4Jn1r20190219000735706379.jpeg    1874618
# 4  02ntxrsyUG4OxVoi20190822033432889200.jpeg    2550168
#
#                                DiagnosisDescriptions  \
# 0  LEFT TIP OF SHOULDER: CONSISTENT WITH MELANOMA...
# 1               STERNUM: LICHENOID ACTINIC KERATOSIS
# 2  LEFT FOREHEAD:  -MODERATELY ATYPICAL JUNCTIONA...
# 3  LEFT ANTERIOR CHEST:  PIGMENTED SEBORRHOEIC KE...
# 4  LEFT PARIETAL SCALP: ACTINIC KERATOSIS WITH AT...
#
#               DiagnosisSCARD  MEL  NV  ...  SCC  UNK  Count_classes     w  \
# 0         Melanoma - in situ    1   0  ...    0    0              1  2317
# 1            Solar keratosis    0   0  ...    0    0              1  2877
# 2  Naevus - dysplastic/Clark    0   1  ...    0    0              1  1783
# 3      Seborrhoeic keratosis    0   0  ...    0    0              1  2295
# 4         IEC/Bowens disease    0   0  ...    0    0              1  2317
#
#       h                              hash                             path  \
# 0  2317  0c6097583cfad9cce5c4cf094be826f7  ../data/images/ISIC_1000000.jpg
# 1  2877  fb7099d23536972d11f825cd7e038c67  ../data/images/ISIC_1000001.jpg
# 2  1783  541e383dd5e78d1da34dae882cbee940  ../data/images/ISIC_1000002.jpg
# 3  2295  ff00ee82c9d240453d6f5da4522cfb6e  ../data/images/ISIC_1000003.jpg
# 4  2317  e89d64eadaf1a1af2e273c001edadda2  ../data/images/ISIC_1000004.jpg
#
#                cell_type  cell_type_idx  train_or_val_or_test
# 0               Melanoma              0                 train
# 1     IEC/Bowens disease              3                 train
# 2                 Naevus              1                 train
# 3  Seborrhoeic keratosis              4                 train
# 4     IEC/Bowens disease              3                 train
#
# [5 rows x 25 columns]

# %%
df_train['cell_type'].value_counts()
# Out:
# Naevus                    3888
# Basal Cell Carcinoma      3181
# IEC/Bowens disease        2560
# Keratosis pilaris         2079
# Seborrhoeic keratosis     1862
# Squamous cell carcinom     710
# Melanoma                   581
# dermatofibroima            219
# vascular lesions           117
# Name: cell_type, dtype: int64

# %%
df_train['cell_type_idx'].value_counts()
# Out:
# 1    3888
# 2    3181
# 3    2560
# 8    2079
# 4    1862
# 7     710
# 0     581
# 5     219
# 6     117
# Name: cell_type_idx, dtype: int64

# %%
# Copy fewer class to balance the number of 7 classes
# we only need to augment the training set.
import math
def balance_frame(frame):
    aug_rate = []
    max_size = 0
    for i in range(9):
        current_size = frame['cell_type_idx'].value_counts()[i]
        if current_size > max_size:
            max_size = current_size

    for i in range(9):
        aug_rate.append(math.floor(max_size/frame['cell_type_idx'].value_counts()[i]))

    for i in range(9):
        if aug_rate[i]:
            frame = frame.append([frame.loc[frame['cell_type_idx'] == i,:]]*(aug_rate[i]-1), ignore_index=True)
    return frame

#df_train = balance_frame(df_train)
#df_train['cell_type_idx'].value_counts()

# %%
# Resetting indexes! Very important!!
df_train = df_train.reset_index()
df_val = df_val.reset_index()
df_test = df_test.reset_index()

# %%
# model building
# feature_extract is a boolean that defines if we are finetuning or feature extracting. 
# If feature_extract = False, the model is finetuned and all model parameters are updated. 
# If feature_extract = True, only the last layer parameters are updated, the others remain fixed.
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # each of these variable is model specific
    model_ft = None
    input_size = 0
    
    if model_name == 'resnet':
        """Resnet18, Resnet34, Resnet50, Resnet101"""
        model_ft = models.resnet50(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224
        
    elif model_name == 'vgg':
        '''VGG11_BN'''
        model_ft = models.vgg11_bn(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[9].in_features
        model_ft.classifier[9] = nn.Linear(num_ftrs, num_classes)
        input_size = 224
        
    elif model_name == 'densenet':
        '''densenet121'''
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 224
    
    elif model_name == 'inception':
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299
    else:
        print("Invalid model name, exiting...")
        exit()
    return model_ft, input_size

# %%
# resnet,vgg,densenet,inception
model_name = 'densenet'
num_classes = 9
feature_extract = False
# Initialize the model for this run
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)
# Define the device:
device = torch.device('cuda:0')
print(device)
# Put the model on the device:
model = model_ft.to(device)
# Out:
# cuda:0

# %%
# norm_mean = (0.49139968, 0.48215827, 0.44653124)
# norm_std = (0.24703233, 0.24348505, 0.26158768)
# define the transformation of the train images.
print(input_size)
train_transform = transforms.Compose([transforms.Resize((input_size,input_size)),transforms.RandomHorizontalFlip(),
                                      transforms.RandomVerticalFlip(),transforms.RandomRotation(20),
                                      transforms.ColorJitter(brightness=0.1, contrast=0.1, hue=0.1),
                                        transforms.ToTensor(), transforms.Normalize(norm_mean, norm_std)])
# define the transformation of the val images.
val_transform = transforms.Compose([transforms.Resize((input_size,input_size)), transforms.ToTensor(),
                                    transforms.Normalize(norm_mean, norm_std)])

test_transform = transforms.Compose([transforms.Resize((input_size,input_size)), transforms.ToTensor(), 
                                     transforms.Normalize(norm_mean, norm_std)])
# Out:
# 224

# %%
# Define a pytorch dataloader for this dataset
class skinlesionDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        # Load data and get label
        X = Image.open(self.df['path'][index])
        y = torch.tensor(int(self.df['cell_type_idx'][index]))

        if self.transform:
            X = self.transform(X)

        return X, y

# %%
# Define the training set using the table train_df and using our defined transitions (train_transform)
training_set = skinlesionDataset(df_train, transform=train_transform)
validation_set = skinlesionDataset(df_val, transform=val_transform)
test_set = skinlesionDataset(df_test, transform=test_transform)

#loaders
train_loader = DataLoader(training_set, batch_size=32, shuffle=True, num_workers=4)
val_loader = DataLoader(validation_set, batch_size=32, shuffle=True, num_workers=4)
test_loader = DataLoader(test_set, batch_size= 32, shuffle=True)

# %%
# trainiter = iter(val_loader)
# features, labels = next(trainiter)
# features.shape, labels.shape

# %%
# we use Adam optimizer, use cross entropy loss as our loss function
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss().to(device)

# %%
# Model training

# %%
# this function is used during training process, to calculation the loss and accuracy
class AverageMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
total_loss_train, total_acc_train = [],[]
def train(train_loader, model, criterion, optimizer, epoch):
    model.train()
    train_loss = AverageMeter()
    train_acc = AverageMeter()
    curr_iter = (epoch - 1) * len(train_loader)
    for i, data in enumerate(train_loader):
        images, labels = data
        N = images.size(0)
        # print('image shape:',images.size(0), 'label shape',labels.size(0))
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)

        optimizer.zero_grad()
        outputs = model(images)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        prediction = outputs.max(1, keepdim=True)[1]
        train_acc.update(prediction.eq(labels.view_as(prediction)).sum().item()/N)
        train_loss.update(loss.item())
        curr_iter += 1
        if (i + 1) % 100 == 0:
            print('[epoch %d], [iter %d / %d], [train loss %.5f], [train acc %.5f]' % (
                epoch, i + 1, len(train_loader), train_loss.avg, train_acc.avg))
            total_loss_train.append(train_loss.avg)
            total_acc_train.append(train_acc.avg)
    return train_loss.avg, train_acc.avg

# %%
def validate(val_loader, model, criterion, optimizer, epoch):
    model.eval()
    val_loss = AverageMeter()
    val_acc = AverageMeter()
    with torch.no_grad():
        for i, data in enumerate(val_loader):
            images, labels = data
            N = images.size(0)
            images = Variable(images).to(device)
            labels = Variable(labels).to(device)

            outputs = model(images)
            prediction = outputs.max(1, keepdim=True)[1]

            val_acc.update(prediction.eq(labels.view_as(prediction)).sum().item()/N)

            val_loss.update(criterion(outputs, labels).item())

    print('------------------------------------------------------------')
    print('[epoch %d], [val loss %.5f], [val acc %.5f]' % (epoch, val_loss.avg, val_acc.avg))
    print('------------------------------------------------------------')
    return val_loss.avg, val_acc.avg

# %%
epoch_num = 50
best_val_acc = 0
total_loss_val, total_acc_val = [],[]
for epoch in range(1, epoch_num+1):
    loss_train, acc_train = train(train_loader, model, criterion, optimizer, epoch)
    loss_val, acc_val = validate(val_loader, model, criterion, optimizer, epoch)
    total_loss_val.append(loss_val)
    total_acc_val.append(acc_val)
    if acc_val > best_val_acc:
        best_val_acc = acc_val
        print('*****************************************************')
        print('best record: [epoch %d], [val loss %.5f], [val acc %.5f]' % (epoch, loss_val, acc_val))
        print('*****************************************************')
# Out:
# [epoch 1], [iter 100 / 475], [train loss 1.58912], [train acc 0.41125]
# [epoch 1], [iter 200 / 475], [train loss 1.58654], [train acc 0.41187]
# [epoch 1], [iter 300 / 475], [train loss 1.58598], [train acc 0.40615]
# [epoch 1], [iter 400 / 475], [train loss 1.57386], [train acc 0.41406]
# ------------------------------------------------------------
# [epoch 1], [val loss 1.49681], [val acc 0.42847]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 1], [val loss 1.49681], [val acc 0.42847]
# *****************************************************
# [epoch 2], [iter 100 / 475], [train loss 1.53308], [train acc 0.42156]
# [epoch 2], [iter 200 / 475], [train loss 1.54842], [train acc 0.41797]
# [epoch 2], [iter 300 / 475], [train loss 1.54356], [train acc 0.42260]
# [epoch 2], [iter 400 / 475], [train loss 1.54733], [train acc 0.42070]
# ------------------------------------------------------------
# [epoch 2], [val loss 1.53372], [val acc 0.42552]
# ------------------------------------------------------------
# [epoch 3], [iter 100 / 475], [train loss 1.52073], [train acc 0.42938]
# [epoch 3], [iter 200 / 475], [train loss 1.52786], [train acc 0.42656]
# [epoch 3], [iter 300 / 475], [train loss 1.53488], [train acc 0.42510]
# [epoch 3], [iter 400 / 475], [train loss 1.52784], [train acc 0.42859]
# ------------------------------------------------------------
# [epoch 3], [val loss 2.35342], [val acc 0.28160]
# ------------------------------------------------------------
# [epoch 4], [iter 100 / 475], [train loss 1.52000], [train acc 0.43469]
# [epoch 4], [iter 200 / 475], [train loss 1.52842], [train acc 0.42594]
# [epoch 4], [iter 300 / 475], [train loss 1.52322], [train acc 0.43125]
# [epoch 4], [iter 400 / 475], [train loss 1.51452], [train acc 0.43633]
# ------------------------------------------------------------
# [epoch 4], [val loss 1.47668], [val acc 0.45799]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 4], [val loss 1.47668], [val acc 0.45799]
# *****************************************************
# [epoch 5], [iter 100 / 475], [train loss 1.49498], [train acc 0.44219]
# [epoch 5], [iter 200 / 475], [train loss 1.47934], [train acc 0.44688]
# [epoch 5], [iter 300 / 475], [train loss 1.49166], [train acc 0.44292]
# [epoch 5], [iter 400 / 475], [train loss 1.48796], [train acc 0.44469]
# ------------------------------------------------------------
# [epoch 5], [val loss 1.49897], [val acc 0.44427]
# ------------------------------------------------------------
# [epoch 6], [iter 100 / 475], [train loss 1.47944], [train acc 0.44781]
# [epoch 6], [iter 200 / 475], [train loss 1.46093], [train acc 0.45937]
# [epoch 6], [iter 300 / 475], [train loss 1.46348], [train acc 0.45667]
# [epoch 6], [iter 400 / 475], [train loss 1.45915], [train acc 0.45797]
# ------------------------------------------------------------
# [epoch 6], [val loss 1.48918], [val acc 0.43924]
# ------------------------------------------------------------
# [epoch 7], [iter 100 / 475], [train loss 1.47060], [train acc 0.44594]
# [epoch 7], [iter 200 / 475], [train loss 1.45087], [train acc 0.45750]
# [epoch 7], [iter 300 / 475], [train loss 1.45286], [train acc 0.45802]
# [epoch 7], [iter 400 / 475], [train loss 1.45101], [train acc 0.45961]
# ------------------------------------------------------------
# [epoch 7], [val loss 1.41831], [val acc 0.47309]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 7], [val loss 1.41831], [val acc 0.47309]
# *****************************************************
# [epoch 8], [iter 100 / 475], [train loss 1.44730], [train acc 0.45969]
# [epoch 8], [iter 200 / 475], [train loss 1.42585], [train acc 0.47234]
# [epoch 8], [iter 300 / 475], [train loss 1.43475], [train acc 0.47052]
# [epoch 8], [iter 400 / 475], [train loss 1.42907], [train acc 0.47320]
# ------------------------------------------------------------
# [epoch 8], [val loss 1.54072], [val acc 0.45503]
# ------------------------------------------------------------
# [epoch 9], [iter 100 / 475], [train loss 1.43036], [train acc 0.47313]
# [epoch 9], [iter 200 / 475], [train loss 1.41163], [train acc 0.47391]
# [epoch 9], [iter 300 / 475], [train loss 1.41155], [train acc 0.47604]
# [epoch 9], [iter 400 / 475], [train loss 1.40655], [train acc 0.47820]
# ------------------------------------------------------------
# [epoch 9], [val loss 1.42659], [val acc 0.46424]
# ------------------------------------------------------------
# [epoch 10], [iter 100 / 475], [train loss 1.42480], [train acc 0.48156]
# [epoch 10], [iter 200 / 475], [train loss 1.41408], [train acc 0.47953]
# [epoch 10], [iter 300 / 475], [train loss 1.41292], [train acc 0.47677]
# [epoch 10], [iter 400 / 475], [train loss 1.40527], [train acc 0.48008]
# ------------------------------------------------------------
# [epoch 10], [val loss 1.39366], [val acc 0.48403]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 10], [val loss 1.39366], [val acc 0.48403]
# *****************************************************
# [epoch 11], [iter 100 / 475], [train loss 1.37777], [train acc 0.49562]
# [epoch 11], [iter 200 / 475], [train loss 1.37009], [train acc 0.49156]
# [epoch 11], [iter 300 / 475], [train loss 1.37086], [train acc 0.49323]
# [epoch 11], [iter 400 / 475], [train loss 1.37647], [train acc 0.49156]
# ------------------------------------------------------------
# [epoch 11], [val loss 1.39599], [val acc 0.48455]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 11], [val loss 1.39599], [val acc 0.48455]
# *****************************************************
# [epoch 12], [iter 100 / 475], [train loss 1.37174], [train acc 0.50031]
# [epoch 12], [iter 200 / 475], [train loss 1.38605], [train acc 0.48828]
# [epoch 12], [iter 300 / 475], [train loss 1.38111], [train acc 0.48958]
# [epoch 12], [iter 400 / 475], [train loss 1.37775], [train acc 0.49000]
# ------------------------------------------------------------
# [epoch 12], [val loss 1.40494], [val acc 0.48264]
# ------------------------------------------------------------
# [epoch 13], [iter 100 / 475], [train loss 1.34417], [train acc 0.49906]
# [epoch 13], [iter 200 / 475], [train loss 1.35610], [train acc 0.49734]
# [epoch 13], [iter 300 / 475], [train loss 1.36500], [train acc 0.49490]
# [epoch 13], [iter 400 / 475], [train loss 1.36084], [train acc 0.49562]
# ------------------------------------------------------------
# [epoch 13], [val loss 1.38186], [val acc 0.49601]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 13], [val loss 1.38186], [val acc 0.49601]
# *****************************************************
# [epoch 14], [iter 100 / 475], [train loss 1.33107], [train acc 0.51719]
# [epoch 14], [iter 200 / 475], [train loss 1.31603], [train acc 0.51641]
# [epoch 14], [iter 300 / 475], [train loss 1.33207], [train acc 0.51010]
# [epoch 14], [iter 400 / 475], [train loss 1.33768], [train acc 0.50609]
# ------------------------------------------------------------
# [epoch 14], [val loss 1.38891], [val acc 0.49809]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 14], [val loss 1.38891], [val acc 0.49809]
# *****************************************************
# [epoch 15], [iter 100 / 475], [train loss 1.32035], [train acc 0.50938]
# [epoch 15], [iter 200 / 475], [train loss 1.32410], [train acc 0.51266]
# [epoch 15], [iter 300 / 475], [train loss 1.33202], [train acc 0.50604]
# [epoch 15], [iter 400 / 475], [train loss 1.32765], [train acc 0.50977]
# ------------------------------------------------------------
# [epoch 15], [val loss 1.34895], [val acc 0.49149]
# ------------------------------------------------------------
# [epoch 16], [iter 100 / 475], [train loss 1.31180], [train acc 0.52781]
# [epoch 16], [iter 200 / 475], [train loss 1.31139], [train acc 0.52328]
# [epoch 16], [iter 300 / 475], [train loss 1.31805], [train acc 0.51729]
# [epoch 16], [iter 400 / 475], [train loss 1.31983], [train acc 0.51570]
# ------------------------------------------------------------
# [epoch 16], [val loss 1.40033], [val acc 0.48976]
# ------------------------------------------------------------
# [epoch 17], [iter 100 / 475], [train loss 1.29566], [train acc 0.52656]
# [epoch 17], [iter 200 / 475], [train loss 1.31491], [train acc 0.51922]
# [epoch 17], [iter 300 / 475], [train loss 1.31458], [train acc 0.51969]
# [epoch 17], [iter 400 / 475], [train loss 1.31689], [train acc 0.51664]
# ------------------------------------------------------------
# [epoch 17], [val loss 1.36428], [val acc 0.48507]
# ------------------------------------------------------------
# [epoch 18], [iter 100 / 475], [train loss 1.30237], [train acc 0.52000]
# [epoch 18], [iter 200 / 475], [train loss 1.28165], [train acc 0.52828]
# [epoch 18], [iter 300 / 475], [train loss 1.28867], [train acc 0.52302]
# [epoch 18], [iter 400 / 475], [train loss 1.28715], [train acc 0.52242]
# ------------------------------------------------------------
# [epoch 18], [val loss 1.35905], [val acc 0.48889]
# ------------------------------------------------------------
# [epoch 19], [iter 100 / 475], [train loss 1.26185], [train acc 0.54250]
# [epoch 19], [iter 200 / 475], [train loss 1.27027], [train acc 0.52984]
# [epoch 19], [iter 300 / 475], [train loss 1.27544], [train acc 0.53031]
# [epoch 19], [iter 400 / 475], [train loss 1.27085], [train acc 0.53391]
# ------------------------------------------------------------
# [epoch 19], [val loss 1.37406], [val acc 0.50139]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 19], [val loss 1.37406], [val acc 0.50139]
# *****************************************************
# [epoch 20], [iter 100 / 475], [train loss 1.25995], [train acc 0.54156]
# [epoch 20], [iter 200 / 475], [train loss 1.26735], [train acc 0.53047]
# [epoch 20], [iter 300 / 475], [train loss 1.26754], [train acc 0.53469]
# [epoch 20], [iter 400 / 475], [train loss 1.26509], [train acc 0.53484]
# ------------------------------------------------------------
# [epoch 20], [val loss 1.35456], [val acc 0.49757]
# ------------------------------------------------------------
# [epoch 21], [iter 100 / 475], [train loss 1.24225], [train acc 0.53844]
# [epoch 21], [iter 200 / 475], [train loss 1.23263], [train acc 0.54484]
# [epoch 21], [iter 300 / 475], [train loss 1.23827], [train acc 0.54646]
# [epoch 21], [iter 400 / 475], [train loss 1.24614], [train acc 0.54336]
# ------------------------------------------------------------
# [epoch 21], [val loss 1.34449], [val acc 0.50972]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 21], [val loss 1.34449], [val acc 0.50972]
# *****************************************************
# [epoch 22], [iter 100 / 475], [train loss 1.22876], [train acc 0.55219]
# [epoch 22], [iter 200 / 475], [train loss 1.23375], [train acc 0.55531]
# [epoch 22], [iter 300 / 475], [train loss 1.23382], [train acc 0.55250]
# [epoch 22], [iter 400 / 475], [train loss 1.23355], [train acc 0.54836]
# ------------------------------------------------------------
# [epoch 22], [val loss 1.32167], [val acc 0.51406]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 22], [val loss 1.32167], [val acc 0.51406]
# *****************************************************
# [epoch 23], [iter 100 / 475], [train loss 1.24280], [train acc 0.53938]
# [epoch 23], [iter 200 / 475], [train loss 1.24493], [train acc 0.54031]
# [epoch 23], [iter 300 / 475], [train loss 1.22917], [train acc 0.54646]
# [epoch 23], [iter 400 / 475], [train loss 1.22451], [train acc 0.54781]
# ------------------------------------------------------------
# [epoch 23], [val loss 1.32415], [val acc 0.51667]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 23], [val loss 1.32415], [val acc 0.51667]
# *****************************************************
# [epoch 24], [iter 100 / 475], [train loss 1.21814], [train acc 0.54812]
# [epoch 24], [iter 200 / 475], [train loss 1.19121], [train acc 0.55766]
# [epoch 24], [iter 300 / 475], [train loss 1.20053], [train acc 0.55771]
# [epoch 24], [iter 400 / 475], [train loss 1.21023], [train acc 0.55609]
# ------------------------------------------------------------
# [epoch 24], [val loss 1.34667], [val acc 0.51389]
# ------------------------------------------------------------
# [epoch 25], [iter 100 / 475], [train loss 1.17926], [train acc 0.57312]
# [epoch 25], [iter 200 / 475], [train loss 1.17922], [train acc 0.57109]
# [epoch 25], [iter 300 / 475], [train loss 1.18952], [train acc 0.56677]
# [epoch 25], [iter 400 / 475], [train loss 1.19259], [train acc 0.56437]
# ------------------------------------------------------------
# [epoch 25], [val loss 1.31282], [val acc 0.51510]
# ------------------------------------------------------------
# [epoch 26], [iter 100 / 475], [train loss 1.14341], [train acc 0.58000]
# [epoch 26], [iter 200 / 475], [train loss 1.17723], [train acc 0.57000]
# [epoch 26], [iter 300 / 475], [train loss 1.18514], [train acc 0.56521]
# [epoch 26], [iter 400 / 475], [train loss 1.18216], [train acc 0.56586]
# ------------------------------------------------------------
# [epoch 26], [val loss 1.31280], [val acc 0.52656]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 26], [val loss 1.31280], [val acc 0.52656]
# *****************************************************
# [epoch 27], [iter 100 / 475], [train loss 1.15037], [train acc 0.57406]
# [epoch 27], [iter 200 / 475], [train loss 1.18000], [train acc 0.56781]
# [epoch 27], [iter 300 / 475], [train loss 1.18093], [train acc 0.56552]
# [epoch 27], [iter 400 / 475], [train loss 1.17253], [train acc 0.57000]
# ------------------------------------------------------------
# [epoch 27], [val loss 1.34059], [val acc 0.52101]
# ------------------------------------------------------------
# [epoch 28], [iter 100 / 475], [train loss 1.14427], [train acc 0.58062]
# [epoch 28], [iter 200 / 475], [train loss 1.13951], [train acc 0.57750]
# [epoch 28], [iter 300 / 475], [train loss 1.14193], [train acc 0.57635]
# [epoch 28], [iter 400 / 475], [train loss 1.13941], [train acc 0.57789]
# ------------------------------------------------------------
# [epoch 28], [val loss 1.36375], [val acc 0.50955]
# ------------------------------------------------------------
# [epoch 29], [iter 100 / 475], [train loss 1.14193], [train acc 0.58062]
# [epoch 29], [iter 200 / 475], [train loss 1.12592], [train acc 0.58875]
# [epoch 29], [iter 300 / 475], [train loss 1.12843], [train acc 0.58760]
# [epoch 29], [iter 400 / 475], [train loss 1.12918], [train acc 0.58594]
# ------------------------------------------------------------
# [epoch 29], [val loss 1.33041], [val acc 0.51285]
# ------------------------------------------------------------
# [epoch 30], [iter 100 / 475], [train loss 1.11287], [train acc 0.60125]
# [epoch 30], [iter 200 / 475], [train loss 1.11359], [train acc 0.59578]
# [epoch 30], [iter 300 / 475], [train loss 1.11362], [train acc 0.59604]
# [epoch 30], [iter 400 / 475], [train loss 1.12501], [train acc 0.59109]
# ------------------------------------------------------------
# [epoch 30], [val loss 1.34782], [val acc 0.51267]
# ------------------------------------------------------------
# [epoch 31], [iter 100 / 475], [train loss 1.08011], [train acc 0.60313]
# [epoch 31], [iter 200 / 475], [train loss 1.08257], [train acc 0.60531]
# [epoch 31], [iter 300 / 475], [train loss 1.09935], [train acc 0.59979]
# [epoch 31], [iter 400 / 475], [train loss 1.09918], [train acc 0.59937]
# ------------------------------------------------------------
# [epoch 31], [val loss 1.33111], [val acc 0.51892]
# ------------------------------------------------------------
# [epoch 32], [iter 100 / 475], [train loss 1.06231], [train acc 0.60500]
# [epoch 32], [iter 200 / 475], [train loss 1.07367], [train acc 0.60609]
# [epoch 32], [iter 300 / 475], [train loss 1.08264], [train acc 0.60062]
# [epoch 32], [iter 400 / 475], [train loss 1.08443], [train acc 0.60000]
# ------------------------------------------------------------
# [epoch 32], [val loss 1.36372], [val acc 0.51042]
# ------------------------------------------------------------
# [epoch 33], [iter 100 / 475], [train loss 1.05011], [train acc 0.61094]
# [epoch 33], [iter 200 / 475], [train loss 1.07444], [train acc 0.60328]
# [epoch 33], [iter 300 / 475], [train loss 1.06634], [train acc 0.60906]
# [epoch 33], [iter 400 / 475], [train loss 1.07194], [train acc 0.60672]
# ------------------------------------------------------------
# [epoch 33], [val loss 1.30298], [val acc 0.52865]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 33], [val loss 1.30298], [val acc 0.52865]
# *****************************************************
# [epoch 34], [iter 100 / 475], [train loss 1.06372], [train acc 0.61281]
# [epoch 34], [iter 200 / 475], [train loss 1.05753], [train acc 0.61141]
# [epoch 34], [iter 300 / 475], [train loss 1.06215], [train acc 0.61271]
# [epoch 34], [iter 400 / 475], [train loss 1.05156], [train acc 0.61570]
# ------------------------------------------------------------
# [epoch 34], [val loss 1.33742], [val acc 0.53316]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 34], [val loss 1.33742], [val acc 0.53316]
# *****************************************************
# [epoch 35], [iter 100 / 475], [train loss 1.02589], [train acc 0.62594]
# [epoch 35], [iter 200 / 475], [train loss 1.00510], [train acc 0.62844]
# [epoch 35], [iter 300 / 475], [train loss 1.01222], [train acc 0.62813]
# [epoch 35], [iter 400 / 475], [train loss 1.03723], [train acc 0.61727]
# ------------------------------------------------------------
# [epoch 35], [val loss 1.36636], [val acc 0.52587]
# ------------------------------------------------------------
# [epoch 36], [iter 100 / 475], [train loss 0.99555], [train acc 0.63438]
# [epoch 36], [iter 200 / 475], [train loss 1.01733], [train acc 0.62516]
# [epoch 36], [iter 300 / 475], [train loss 1.02480], [train acc 0.62281]
# [epoch 36], [iter 400 / 475], [train loss 1.02208], [train acc 0.62555]
# ------------------------------------------------------------
# [epoch 36], [val loss 1.36892], [val acc 0.52552]
# ------------------------------------------------------------
# [epoch 37], [iter 100 / 475], [train loss 0.95272], [train acc 0.64219]
# [epoch 37], [iter 200 / 475], [train loss 0.98707], [train acc 0.63344]
# [epoch 37], [iter 300 / 475], [train loss 1.00809], [train acc 0.62594]
# [epoch 37], [iter 400 / 475], [train loss 1.00874], [train acc 0.62703]
# ------------------------------------------------------------
# [epoch 37], [val loss 1.36157], [val acc 0.52413]
# ------------------------------------------------------------
# [epoch 38], [iter 100 / 475], [train loss 0.94395], [train acc 0.65250]
# [epoch 38], [iter 200 / 475], [train loss 0.97289], [train acc 0.63922]
# [epoch 38], [iter 300 / 475], [train loss 0.99234], [train acc 0.63521]
# [epoch 38], [iter 400 / 475], [train loss 0.98851], [train acc 0.63484]
# ------------------------------------------------------------
# [epoch 38], [val loss 1.38921], [val acc 0.52760]
# ------------------------------------------------------------
# [epoch 39], [iter 100 / 475], [train loss 0.97381], [train acc 0.63406]
# [epoch 39], [iter 200 / 475], [train loss 0.97495], [train acc 0.63984]
# [epoch 39], [iter 300 / 475], [train loss 0.97535], [train acc 0.63781]
# [epoch 39], [iter 400 / 475], [train loss 0.97358], [train acc 0.64234]
# ------------------------------------------------------------
# [epoch 39], [val loss 1.37123], [val acc 0.53663]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 39], [val loss 1.37123], [val acc 0.53663]
# *****************************************************
# [epoch 40], [iter 100 / 475], [train loss 0.92085], [train acc 0.67125]
# [epoch 40], [iter 200 / 475], [train loss 0.91143], [train acc 0.67016]
# [epoch 40], [iter 300 / 475], [train loss 0.92814], [train acc 0.66219]
# [epoch 40], [iter 400 / 475], [train loss 0.94010], [train acc 0.65820]
# ------------------------------------------------------------
# [epoch 40], [val loss 1.42757], [val acc 0.52153]
# ------------------------------------------------------------
# [epoch 41], [iter 100 / 475], [train loss 0.92408], [train acc 0.66719]
# [epoch 41], [iter 200 / 475], [train loss 0.92477], [train acc 0.66281]
# [epoch 41], [iter 300 / 475], [train loss 0.92646], [train acc 0.66333]
# [epoch 41], [iter 400 / 475], [train loss 0.92672], [train acc 0.66242]
# ------------------------------------------------------------
# [epoch 41], [val loss 1.38385], [val acc 0.52031]
# ------------------------------------------------------------
# [epoch 42], [iter 100 / 475], [train loss 0.90249], [train acc 0.66219]
# [epoch 42], [iter 200 / 475], [train loss 0.91373], [train acc 0.66766]
# [epoch 42], [iter 300 / 475], [train loss 0.90475], [train acc 0.67010]
# [epoch 42], [iter 400 / 475], [train loss 0.91428], [train acc 0.66680]
# ------------------------------------------------------------
# [epoch 42], [val loss 1.40577], [val acc 0.51771]
# ------------------------------------------------------------
# [epoch 43], [iter 100 / 475], [train loss 0.85832], [train acc 0.68375]
# [epoch 43], [iter 200 / 475], [train loss 0.87860], [train acc 0.68000]
# [epoch 43], [iter 300 / 475], [train loss 0.87932], [train acc 0.67865]
# [epoch 43], [iter 400 / 475], [train loss 0.88695], [train acc 0.67656]
# ------------------------------------------------------------
# [epoch 43], [val loss 1.41293], [val acc 0.53611]
# ------------------------------------------------------------
# [epoch 44], [iter 100 / 475], [train loss 0.87336], [train acc 0.67844]
# [epoch 44], [iter 200 / 475], [train loss 0.86995], [train acc 0.67766]
# [epoch 44], [iter 300 / 475], [train loss 0.85950], [train acc 0.68365]
# [epoch 44], [iter 400 / 475], [train loss 0.86849], [train acc 0.68188]
# ------------------------------------------------------------
# [epoch 44], [val loss 1.44422], [val acc 0.52413]
# ------------------------------------------------------------
# [epoch 45], [iter 100 / 475], [train loss 0.83375], [train acc 0.69594]
# [epoch 45], [iter 200 / 475], [train loss 0.86710], [train acc 0.68750]
# [epoch 45], [iter 300 / 475], [train loss 0.86860], [train acc 0.68563]
# [epoch 45], [iter 400 / 475], [train loss 0.86395], [train acc 0.68578]
# ------------------------------------------------------------
# [epoch 45], [val loss 1.45318], [val acc 0.54080]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 45], [val loss 1.45318], [val acc 0.54080]
# *****************************************************
# [epoch 46], [iter 100 / 475], [train loss 0.83465], [train acc 0.69563]
# [epoch 46], [iter 200 / 475], [train loss 0.81847], [train acc 0.70047]
# [epoch 46], [iter 300 / 475], [train loss 0.83023], [train acc 0.69760]
# [epoch 46], [iter 400 / 475], [train loss 0.83207], [train acc 0.69727]
# ------------------------------------------------------------
# [epoch 46], [val loss 1.48981], [val acc 0.52552]
# ------------------------------------------------------------
# [epoch 47], [iter 100 / 475], [train loss 0.77769], [train acc 0.72031]
# [epoch 47], [iter 200 / 475], [train loss 0.78247], [train acc 0.71500]
# [epoch 47], [iter 300 / 475], [train loss 0.79349], [train acc 0.71062]
# [epoch 47], [iter 400 / 475], [train loss 0.81474], [train acc 0.70258]
# ------------------------------------------------------------
# [epoch 47], [val loss 1.43654], [val acc 0.52257]
# ------------------------------------------------------------
# [epoch 48], [iter 100 / 475], [train loss 0.74466], [train acc 0.72656]
# [epoch 48], [iter 200 / 475], [train loss 0.76934], [train acc 0.71656]
# [epoch 48], [iter 300 / 475], [train loss 0.78097], [train acc 0.71271]
# [epoch 48], [iter 400 / 475], [train loss 0.79152], [train acc 0.71125]
# ------------------------------------------------------------
# [epoch 48], [val loss 1.50085], [val acc 0.53247]
# ------------------------------------------------------------
# [epoch 49], [iter 100 / 475], [train loss 0.74011], [train acc 0.73188]
# [epoch 49], [iter 200 / 475], [train loss 0.75956], [train acc 0.72391]
# [epoch 49], [iter 300 / 475], [train loss 0.77134], [train acc 0.72167]
# [epoch 49], [iter 400 / 475], [train loss 0.77401], [train acc 0.72008]
# ------------------------------------------------------------
# [epoch 49], [val loss 1.47134], [val acc 0.53264]
# ------------------------------------------------------------
# [epoch 50], [iter 100 / 475], [train loss 0.73048], [train acc 0.74000]
# [epoch 50], [iter 200 / 475], [train loss 0.73885], [train acc 0.73219]
# [epoch 50], [iter 300 / 475], [train loss 0.75885], [train acc 0.72354]
# [epoch 50], [iter 400 / 475], [train loss 0.75538], [train acc 0.72453]
# ------------------------------------------------------------
# [epoch 50], [val loss 1.55900], [val acc 0.52170]
# ------------------------------------------------------------

# %%
def test(model):
    tot_labels = torch.tensor([], device='cuda:0')
    tot_outputs= torch.tensor([], device='cuda:0')
    correct = 0
    total = 0
    with torch.no_grad():
        for i, data in enumerate(test_loader, 0):
            images, labels = data[0].to(device), data[1].to(device)
            outputs = model(images)
            
                
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            if len(tot_labels) == 0:
                tot_labels = labels
                tot_outputs = predicted
            else:
                tot_labels = torch.cat((tot_labels, labels), 0)
                tot_outputs = torch.cat((tot_outputs, predicted), 0)
                
                
    return (correct * 100 / total)

# %%
test(model)
# Out:
# 51.21052631578947

# %%
img_category = {lesion_category[k]: k for k in lesion_category.keys()}
print(img_category)
# Out:
# {0: 'MEL', 1: 'NV', 2: 'BCC', 3: 'AK', 4: 'BKL', 5: 'DF', 6: 'VASC', 7: 'SCC', 8: 'UNK'}

# %%
def test_by_class(model):
    class_correct = list(0. for i in range(9))
    class_total = list(0. for i in range(9))
    correct = 0
    total = 0
    with torch.no_grad():
        for data in test_loader:
            images, labels = data[0].to(device), data[1].to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            
            _, acc_pred = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (acc_pred == labels).sum().item()
            
            
            
            
            c = (predicted == labels)
            datalen = len(data[0])
            #print(datalen)
            for i in range(datalen):
                try:
                    label = labels[i]
                    class_correct[label] += c[i].item()
                    class_total[label] += 1
                except:
                    pass
    print('Accuracy: ', (correct * 100 / total))
    for i in range(9):
        print(img_category[i], class_correct[i], '/', class_total[i])
        print('Accuracy of %20s : %3d %%' % (img_category[i], 100 * class_correct[i]/class_total[i]))

# %%
test_by_class(model)
# Out:
# Accuracy:  51.21052631578947
# MEL 22.0 / 72.0
# Accuracy of                  MEL :  30 %
# NV 375.0 / 486.0
# Accuracy of                   NV :  77 %
# BCC 255.0 / 398.0
# Accuracy of                  BCC :  64 %
# AK 132.0 / 320.0
# Accuracy of                   AK :  41 %
# BKL 80.0 / 233.0
# Accuracy of                  BKL :  34 %
# DF 8.0 / 27.0
# Accuracy of                   DF :  29 %
# VASC 3.0 / 15.0
# Accuracy of                 VASC :  20 %
# SCC 26.0 / 89.0
# Accuracy of                  SCC :  29 %
# UNK 72.0 / 260.0
# Accuracy of                  UNK :  27 %

# %%
fig = plt.figure(num = 2)
fig1 = fig.add_subplot(2,1,1)
fig2 = fig.add_subplot(2,1,2)
fig1.plot(total_loss_train, label = 'training loss')
fig1.plot(total_loss_val, label = 'validation loss')
fig2.plot(total_acc_train, label = 'training accuracy')
fig2.plot(total_acc_val, label = 'validation accuracy')
plt.legend()
plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
model.eval()
y_label = []
y_predict = []
with torch.no_grad():
    for i, data in enumerate(test_loader):
        images, labels = data
        N = images.size(0)
        images = Variable(images).to(device)
        outputs = model(images)
        prediction = outputs.max(1, keepdim=True)[1]
        y_label.extend(labels.cpu().numpy())
        y_predict.extend(np.squeeze(prediction.cpu().numpy().T))

# compute the confusion matrix
confusion_mtx = confusion_matrix(y_label, y_predict)
# plot the confusion matrix
plot_labels = lesion_category.keys()
plot_confusion_matrix(confusion_mtx, plot_labels)
